# %%
import pandas as pd

# %%
df = pd.read_html('https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/', header=0)
df[0]
# Out:
#     POS                                   TITLE                    ARTIST  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %%
#1
df[0].rename(columns={'TITLE':'TYTUŁ', 'ARTIST':'ARTYSTA', 'YEAR': 'ROK', 'HIGH POSN':'MAX POZ'}, inplace=True)
df[0]
# Out:
#     POS                                   TYTUŁ                   ARTYSTA  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %%
#2
df[0]['ARTYSTA'].nunique()
# Out:
# 47

# %%
#3
df[0]['ARTYSTA'].value_counts().head(3)
# Out:
# COLDPLAY         3
# TAKE THAT        3
# FLEETWOOD MAC    2
# Name: ARTYSTA, dtype: int64

# %%
#4
df[0].rename(str.capitalize, axis='columns', inplace=True)
df[0]
# Out:
#     Pos                                   Tytuł                   Artysta  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %%
#5
df[0].drop('Max poz', axis=1, inplace=True)
df[0]
# Out:
#     Pos                                   Tytuł                   Artysta  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %%
#6
df[0]['Rok'].value_counts()[df[0]['Rok'].value_counts() == df[0]['Rok'].value_counts().max()]
# Out:
# 2000    4
# 1987    4
# Name: Rok, dtype: int64

# %%
#7
((df[0]['Rok'] >= 1960) & (df[0]['Rok'] <= 1990)).sum()
# Out:
# 22

# %%
#8
df[0]['Rok'].max()
# Out:
# 2015

# %%
#9
df = df[0].groupby('Artysta')['Rok', 'Tytuł'].min().reset_index()

# %%
df
# Out:
#                      Artysta   Rok                             Tytuł
# 0                       ABBA  1975              GOLD - GREATEST HITS
# 1                      ADELE  2011                                21
# 2          ALANIS MORISSETTE  1995                JAGGED LITTLE PILL
# 3              AMY WINEHOUSE  2006                     BACK TO BLACK
# 4                    BEATLES  1967                                 1
# 5   BOB MARLEY & THE WAILERS  1984                            LEGEND
# 6                   COLDPLAY  2000       A RUSH OF BLOOD TO THE HEAD
# 7                      CORRS  1997                   TALK ON CORNERS
# 8                 DAVID GRAY  1998                      WHITE LADDER
# 9                       DIDO  2000                     LIFE FOR RENT
# 10              DIRE STRAITS  1985                  BROTHERS IN ARMS
# 11                ED SHEERAN  2014                                 X
# 12                    EMINEM  2000           THE MARSHALL MATHERS LP
# ...

# %%
#10
df.to_csv('youngest_album.csv')
